# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Importing my dataset

suicide_by_profession = pd.read_csv("Profession_profile_of_suicide_victims_state.csv")

# %%
#Information about the data

suicide_by_profession.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   STATE/UT                   6840 non-null   object
#  1   Year                       6840 non-null   int64
#  2   CAUSE                      6840 non-null   object
#  3   Male upto 14 years         6840 non-null   int64
#  4   Male 15-29 years           6840 non-null   int64
#  5   Male 30-44 years           6840 non-null   int64
#  6   Male 45-59 years           6840 non-null   int64
#  7   Male 60 years and above    6840 non-null   int64
#  8   Total Male                 6840 non-null   int64
#  9   Female upto 14 years       6840 non-null   int64
#  10  Female 15-29 years         6840 non-null   int64
#  11  Female 30-44 years         6840 non-null   int64
#  12  Female 45-59 years         6840 non-null   int64
# ...

# %%
#Having a glance at the first few rows

suicide_by_profession.head()
# Out:
#          STATE/UT  Year                      CAUSE  Male upto 14 years  \
# 0  ANDHRA PRADESH  2001                 House Wife                   0
# 1  ANDHRA PRADESH  2001       Service (Government)                   0
# 2  ANDHRA PRADESH  2001          Service (Private)                   1
# 3  ANDHRA PRADESH  2001  Public Sector Undertaking                   0
# 4  ANDHRA PRADESH  2001                    Student                  56
#
#    Male 15-29 years  Male 30-44 years  Male 45-59 years  \
# 0                 0                 0                 0
# 1                34                57                44
# 2               250               275               138
# 3                32                36                29
# 4               202                19                18
#
#    Male 60 years and above  Total Male  Female upto 14 years  \
# 0                        0           0                     0
# 1                        0         135                     0
# ...

# %%
#Having a glance at the last few rows

suicide_by_profession.tail()
# Out:
#                STATE/UT  Year                    CAUSE  Male upto 14 years  \
# 6835  TOTAL (ALL INDIA)  2012           Retired Person                   0
# 6836  TOTAL (ALL INDIA)  2012  Others (Please Specify)                 307
# 6837  TOTAL (ALL INDIA)  2012                    Total                1120
# 6838  TOTAL (ALL INDIA)  2012           Total Salaried                  21
# 6839  TOTAL (ALL INDIA)  2012      Total Self-employed                 217
#
#       Male 15-29 years  Male 30-44 years  Male 45-59 years  \
# 6835                 9                19               184
# 6836              4013              5696              3525
# 6837             23398             28486             19197
# 6838              4025              5191              3075
# 6839             10123             14757             10616
#
#       Male 60 years and above  Total Male  Female upto 14 years  \
# 6835                      520         732                     5
# ...

# %%
#Checking data types of all columns

suicide_by_profession.dtypes
# Out:
# STATE/UT                     object
# Year                          int64
# CAUSE                        object
# Male upto 14 years            int64
# Male 15-29 years              int64
# Male 30-44 years              int64
# Male 45-59 years              int64
# Male 60 years and above       int64
# Total Male                    int64
# Female upto 14 years          int64
# Female 15-29 years            int64
# Female 30-44 years            int64
# Female 45-59 years            int64
# Female 60 years and above     int64
# Total Female                  int64
# Grand Total                   int64
# dtype: object

# %%
#Renaming the Cause column as it is misleading

suicide_by_profession = suicide_by_profession.rename(columns = {"CAUSE": "Profession"})

# %%
#Making sure if the column has been renamed

suicide_by_profession.head()
# Out:
#          STATE/UT  Year                 Profession  Male upto 14 years  \
# 0  ANDHRA PRADESH  2001                 House Wife                   0
# 1  ANDHRA PRADESH  2001       Service (Government)                   0
# 2  ANDHRA PRADESH  2001          Service (Private)                   1
# 3  ANDHRA PRADESH  2001  Public Sector Undertaking                   0
# 4  ANDHRA PRADESH  2001                    Student                  56
#
#    Male 15-29 years  Male 30-44 years  Male 45-59 years  \
# 0                 0                 0                 0
# 1                34                57                44
# 2               250               275               138
# 3                32                36                29
# 4               202                19                18
#
#    Male 60 years and above  Total Male  Female upto 14 years  \
# 0                        0           0                     0
# 1                        0         135                     0
# ...

# %%
#Finding the null values

print(suicide_by_profession.isna().sum())
# Out:
# STATE/UT                     0
# Year                         0
# Profession                   0
# Male upto 14 years           0
# Male 15-29 years             0
# Male 30-44 years             0
# Male 45-59 years             0
# Male 60 years and above      0
# Total Male                   0
# Female upto 14 years         0
# Female 15-29 years           0
# Female 30-44 years           0
# Female 45-59 years           0
# Female 60 years and above    0
# Total Female                 0
# Grand Total                  0
# dtype: int64

# %%
#Year of interest is 2011, retrieving suicide data for this specific year

suicide_by_profession.loc[suicide_by_profession['Year'] == 2011]
# Out:
#                STATE/UT  Year                 Profession  Male upto 14 years  \
# 150      ANDHRA PRADESH  2011                 House Wife                   0
# 151      ANDHRA PRADESH  2011       Service (Government)                   0
# 152      ANDHRA PRADESH  2011          Service (Private)                   0
# 153      ANDHRA PRADESH  2011  Public Sector Undertaking                   0
# 154      ANDHRA PRADESH  2011                    Student                  45
# ...                 ...   ...                        ...                 ...
# 6820  TOTAL (ALL INDIA)  2011             Retired Person                   0
# 6821  TOTAL (ALL INDIA)  2011    Others (Please Specify)                 611
# 6822  TOTAL (ALL INDIA)  2011                      Total                1574
# 6823  TOTAL (ALL INDIA)  2011             Total Salaried                  15
# 6824  TOTAL (ALL INDIA)  2011        Total Self-employed                 263
#
# ...

# %%
#Checking the different fields suicide victims were working in

suicide_by_profession['Profession'].value_counts().count()
# Out:
# 14

# %%
#The dataset has 14 different categories of profession

# %%
#Checking out the categories

suicide_by_profession['Profession'].value_counts().index
# Out:
# Index(['Others (Please Specify)', 'Student', 'Professional Activity',
#        'House Wife', 'Service (Government)', 'Public Sector Undertaking',
#        'Farming/Agriculture Activity', 'Total Self-employed', 'Retired Person',
#        'Service (Private)', 'Total', 'Self-employed (Business activity)',
#        'Unemployed', 'Total Salaried'],
#       dtype='object')

# %%
#Total doesn't seem like a category,Others(Please specify) won't be useful enough for analysis by profession

# %%
#Checking the total number of states and Union territories the data is available for

suicide_by_profession['STATE/UT'].value_counts().count()
# Out:
# 38

# %%
#Checking the states the data is available for

suicide_by_profession['STATE/UT'].value_counts().index
# Out:
# Index(['SIKKIM', 'NAGALAND', 'ODISHA', 'KERALA', 'PUNJAB', 'KARNATAKA',
#        'ARUNACHAL PRADESH', 'MADHYA PRADESH', 'TAMIL NADU', 'MAHARASHTRA',
#        'PUDUCHERRY', 'UTTARAKHAND', 'TOTAL (STATES)', 'HIMACHAL PRADESH',
#        'TRIPURA', 'JAMMU & KASHMIR', 'MEGHALAYA', 'HARYANA', 'LAKSHADWEEP',
#        'MANIPUR', 'WEST BENGAL', 'D & N HAVELI', 'CHANDIGARH', 'RAJASTHAN',
#        'TOTAL (UTs)', 'JHARKHAND', 'A & N ISLANDS', 'DAMAN & DIU',
#        'TOTAL (ALL INDIA)', 'GUJARAT', 'UTTAR PRADESH', 'BIHAR', 'DELHI (UT)',
#        'ASSAM', 'ANDHRA PRADESH', 'CHHATTISGARH', 'MIZORAM', 'GOA'],
#       dtype='object')

# %%
# TOTAL (STATES),TOTAL (UTs), TOTAL (ALL INDIA) doesn't seem like a state/UT category at all, they must be representing the total suicide count

# %%
#The data contains number of suicide victims divided by their gender. Exploring the two corresponding count of these two groups(all further exploration is done for Year 2011)

state_data_2011 = suicide_by_profession[(suicide_by_profession['Year'] == 2011) & (suicide_by_profession['Profession'] == 'Total')]
                                    
state_data_2011
# Out:
#                STATE/UT  Year Profession  Male upto 14 years  \
# 162      ANDHRA PRADESH  2011      Total                 112
# 342   ARUNACHAL PRADESH  2011      Total                   4
# 522               ASSAM  2011      Total                  20
# 702               BIHAR  2011      Total                  16
# 882        CHHATTISGARH  2011      Total                 102
# 1062                GOA  2011      Total                   5
# 1242            GUJARAT  2011      Total                  35
# 1422            HARYANA  2011      Total                  70
# 1602   HIMACHAL PRADESH  2011      Total                   5
# 1782    JAMMU & KASHMIR  2011      Total                   4
# 1962          JHARKHAND  2011      Total                  13
# 2142          KARNATAKA  2011      Total                 220
# 2322             KERALA  2011      Total                  29
# 2502     MADHYA PRADESH  2011      Total                 156
# ...

# %%
state_data_2011 = state_data_2011[state_data_2011["STATE/UT"].str.contains("TOTAL")==False]

state_data_2011
# Out:
#                STATE/UT  Year Profession  Male upto 14 years  \
# 162      ANDHRA PRADESH  2011      Total                 112
# 342   ARUNACHAL PRADESH  2011      Total                   4
# 522               ASSAM  2011      Total                  20
# 702               BIHAR  2011      Total                  16
# 882        CHHATTISGARH  2011      Total                 102
# 1062                GOA  2011      Total                   5
# 1242            GUJARAT  2011      Total                  35
# 1422            HARYANA  2011      Total                  70
# 1602   HIMACHAL PRADESH  2011      Total                   5
# 1782    JAMMU & KASHMIR  2011      Total                   4
# 1962          JHARKHAND  2011      Total                  13
# 2142          KARNATAKA  2011      Total                 220
# 2322             KERALA  2011      Total                  29
# 2502     MADHYA PRADESH  2011      Total                 156
# ...

# %%
state_data_2011.plot(x="STATE/UT", y=["Total Male", "Total Female"], kind="bar")
plt.ylabel("SUICIDE COUNT")
plt.title("State wise suicide count by gender")
plt.show()

# %%
#Average suicide rate for unemployed men and women would be something of consideration considering the project objective, i would wish to explore this summary statistics

unemployed_data = suicide_by_profession[(suicide_by_profession['Year'] == 2011) & (suicide_by_profession['Profession'] == 'Unemployed')]

# %%
unemployed_data
# Out:
#                STATE/UT  Year  Profession  Male upto 14 years  \
# 155      ANDHRA PRADESH  2011  Unemployed                   0
# 335   ARUNACHAL PRADESH  2011  Unemployed                   0
# 515               ASSAM  2011  Unemployed                   0
# 695               BIHAR  2011  Unemployed                   0
# 875        CHHATTISGARH  2011  Unemployed                   3
# 1055                GOA  2011  Unemployed                   1
# 1235            GUJARAT  2011  Unemployed                   2
# 1415            HARYANA  2011  Unemployed                   4
# 1595   HIMACHAL PRADESH  2011  Unemployed                   0
# 1775    JAMMU & KASHMIR  2011  Unemployed                   0
# 1955          JHARKHAND  2011  Unemployed                   0
# 2135          KARNATAKA  2011  Unemployed                   0
# 2315             KERALA  2011  Unemployed                   0
# 2495     MADHYA PRADESH  2011  Unemployed                   6
# ...

# %%
unemployed_data = unemployed_data[unemployed_data["STATE/UT"].str.contains("TOTAL")==False]

unemployed_data
# Out:
#                STATE/UT  Year  Profession  Male upto 14 years  \
# 155      ANDHRA PRADESH  2011  Unemployed                   0
# 335   ARUNACHAL PRADESH  2011  Unemployed                   0
# 515               ASSAM  2011  Unemployed                   0
# 695               BIHAR  2011  Unemployed                   0
# 875        CHHATTISGARH  2011  Unemployed                   3
# 1055                GOA  2011  Unemployed                   1
# 1235            GUJARAT  2011  Unemployed                   2
# 1415            HARYANA  2011  Unemployed                   4
# 1595   HIMACHAL PRADESH  2011  Unemployed                   0
# 1775    JAMMU & KASHMIR  2011  Unemployed                   0
# 1955          JHARKHAND  2011  Unemployed                   0
# 2135          KARNATAKA  2011  Unemployed                   0
# 2315             KERALA  2011  Unemployed                   0
# 2495     MADHYA PRADESH  2011  Unemployed                   6
# ...

# %%
unemployed_data.describe()
# Out:
#          Year  Male upto 14 years  Male 15-29 years  Male 30-44 years  \
# count    35.0           35.000000         35.000000         35.000000
# mean   2011.0            1.857143         83.371429         99.400000
# std       0.0            5.861855        114.557483        158.242591
# min    2011.0            0.000000          0.000000          0.000000
# 25%    2011.0            0.000000          4.000000          5.500000
# 50%    2011.0            0.000000         14.000000         15.000000
# 75%    2011.0            1.000000        140.500000        147.500000
# max    2011.0           32.000000        408.000000        638.000000
#
#        Male 45-59 years  Male 60 years and above   Total Male  \
# count          35.00000                35.000000    35.000000
# mean           49.20000                11.228571   245.057143
# std           106.40262                26.094946   383.117087
# min             0.00000                 0.000000     0.000000
# ...

# %%
#The above result uncovers that on an average, 245 unemployed men committed suicide per state whereas 52 unemployed women committed suicide per state in 2011

# %%
#Having a glance at distribution of suicide victims by their age group can be useful,by having both genders of similar age group in one group

plot_data = suicide_by_profession[(suicide_by_profession['Year'] == 2011) & (suicide_by_profession['Profession'] == 'Total')]
                                    
plot_data
# Out:
#                STATE/UT  Year Profession  Male upto 14 years  \
# 162      ANDHRA PRADESH  2011      Total                 112
# 342   ARUNACHAL PRADESH  2011      Total                   4
# 522               ASSAM  2011      Total                  20
# 702               BIHAR  2011      Total                  16
# 882        CHHATTISGARH  2011      Total                 102
# 1062                GOA  2011      Total                   5
# 1242            GUJARAT  2011      Total                  35
# 1422            HARYANA  2011      Total                  70
# 1602   HIMACHAL PRADESH  2011      Total                   5
# 1782    JAMMU & KASHMIR  2011      Total                   4
# 1962          JHARKHAND  2011      Total                  13
# 2142          KARNATAKA  2011      Total                 220
# 2322             KERALA  2011      Total                  29
# 2502     MADHYA PRADESH  2011      Total                 156
# ...

# %%
plot_data.tail()
# Out:
#                STATE/UT  Year Profession  Male upto 14 years  \
# 6102         DELHI (UT)  2011      Total                  18
# 6282        LAKSHADWEEP  2011      Total                   0
# 6462         PUDUCHERRY  2011      Total                   2
# 6642        TOTAL (UTs)  2011      Total                  22
# 6822  TOTAL (ALL INDIA)  2011      Total                1574
#
#       Male 15-29 years  Male 30-44 years  Male 45-59 years  \
# 6102               622               367               127
# 6282                 0                 0                 0
# 6462                93               144               122
# 6642               797               579               295
# 6822             26604             31400             20507
#
#       Male 60 years and above  Total Male  Female upto 14 years  \
# 6102                       34        1168                    19
# 6282                        0           0                     0
# ...

# %%
y= (plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Male upto 14 years'] + plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Female upto 14 years'])/plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Grand Total']

y1 = (plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Male 15-29 years'] + plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Female 15-29 years'])/plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Grand Total']

y2 = (plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Male 30-44 years'] + plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Female 30-44 years'])/plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Grand Total']


y3 = (plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Male 45-59 years'] + plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Female 45-59 years'])/plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Grand Total']

y4 = (plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Male 60 years and above'] + 
      plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Female 60 years and above'])/plot_data.loc[plot_data['STATE/UT'] == 'TOTAL (ALL INDIA)', 'Grand Total']

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
my_age_data = {'Age group':['upto 14 years', '15-29 years', '30-44 years', '45-59 years','60 years old and above'],
               'Percenatge':[y[6822],y1[6822],y2[6822],y3[6822],y4[6822]]}
 
# Create DataFrame
age_df = pd.DataFrame(my_age_data)

# %%
Percentage = [y[6822],y1[6822],y2[6822],y3[6822],y4[6822]]
Age_group = ['upto 14 years', '15-29 years', '30-44 years', '45-59 years','60 years old and above']
age_df = pd.DataFrame({"Age group" : Age_group, "Percentage" : Percentage})
age_df
# Out:
#                 Age group  Percentage
# 0           upto 14 years    0.022384
# 1             15-29 years    0.354125
# 2             30-44 years    0.340856
# 3             45-59 years    0.203090
# 4  60 years old and above    0.079544

# %%
ax = age_df.plot(y="Percentage", kind="pie", labels = age_df["Age group"], autopct = '%1.0f%%', legend=False, title='Percentage of suicide victims by age')

ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %%
#Another important category in the dataset is profession, it'd be helpful to explore suicide victims categorized by their profession
prof_by_gender = suicide_by_profession[(suicide_by_profession['Year'] == 2011)]

# %%
prof_by_gender
# Out:
#                STATE/UT  Year                 Profession  Male upto 14 years  \
# 150      ANDHRA PRADESH  2011                 House Wife                   0
# 151      ANDHRA PRADESH  2011       Service (Government)                   0
# 152      ANDHRA PRADESH  2011          Service (Private)                   0
# 153      ANDHRA PRADESH  2011  Public Sector Undertaking                   0
# 154      ANDHRA PRADESH  2011                    Student                  45
# ...                 ...   ...                        ...                 ...
# 6820  TOTAL (ALL INDIA)  2011             Retired Person                   0
# 6821  TOTAL (ALL INDIA)  2011    Others (Please Specify)                 611
# 6822  TOTAL (ALL INDIA)  2011                      Total                1574
# 6823  TOTAL (ALL INDIA)  2011             Total Salaried                  15
# 6824  TOTAL (ALL INDIA)  2011        Total Self-employed                 263
#
# ...

# %%
prof_by_gender = prof_by_gender[prof_by_gender["STATE/UT"].str.contains("TOTAL")==False]
prof_by_gender
# Out:
#             STATE/UT  Year                 Profession  Male upto 14 years  \
# 150   ANDHRA PRADESH  2011                 House Wife                   0
# 151   ANDHRA PRADESH  2011       Service (Government)                   0
# 152   ANDHRA PRADESH  2011          Service (Private)                   0
# 153   ANDHRA PRADESH  2011  Public Sector Undertaking                   0
# 154   ANDHRA PRADESH  2011                    Student                  45
# ...              ...   ...                        ...                 ...
# 6460      PUDUCHERRY  2011             Retired Person                   0
# 6461      PUDUCHERRY  2011    Others (Please Specify)                   0
# 6462      PUDUCHERRY  2011                      Total                   2
# 6463      PUDUCHERRY  2011             Total Salaried                   0
# 6464      PUDUCHERRY  2011        Total Self-employed                   0
#
#       Male 15-29 years  Male 30-44 years  Male 45-59 years  \
# ...

# %%
prof_by_gender = prof_by_gender[prof_by_gender["Profession"].str.contains("Total")==False]

# %%
prof_by_gender['Profession'].value_counts().index
# Out:
# Index(['Others (Please Specify)', 'Farming/Agriculture Activity', 'Unemployed',
#        'Public Sector Undertaking', 'Student', 'Professional Activity',
#        'Service (Government)', 'Self-employed (Business activity)',
#        'Retired Person', 'House Wife', 'Service (Private)'],
#       dtype='object')

# %%
prof_by_gender['STATE/UT'].value_counts().index
# Out:
# Index(['DAMAN & DIU', 'MAHARASHTRA', 'D & N HAVELI', 'A & N ISLANDS',
#        'CHANDIGARH', 'UTTAR PRADESH', 'HARYANA', 'TAMIL NADU', 'WEST BENGAL',
#        'ARUNACHAL PRADESH', 'UTTARAKHAND', 'CHHATTISGARH', 'PUNJAB',
#        'KARNATAKA', 'GOA', 'BIHAR', 'MADHYA PRADESH', 'MEGHALAYA', 'JHARKHAND',
#        'MANIPUR', 'ODISHA', 'MIZORAM', 'PUDUCHERRY', 'SIKKIM',
#        'JAMMU & KASHMIR', 'NAGALAND', 'DELHI (UT)', 'ANDHRA PRADESH',
#        'TRIPURA', 'GUJARAT', 'ASSAM', 'HIMACHAL PRADESH', 'LAKSHADWEEP',
#        'KERALA', 'RAJASTHAN'],
#       dtype='object')

# %%
x = prof_by_gender.loc [prof_by_gender['Profession'] == 'Others (Please Specify)', 'Total Male'].sum()
x1 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Farming/Agriculture Activity', 'Total Male'].sum()
x2 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Unemployed', 'Total Male'].sum()
x3 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Public Sector Undertaking', 'Total Male'].sum()
x4 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Student', 'Total Male'].sum()
x5 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Professional Activity','Total Male'].sum()
x6 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Service (Government)', 'Total Male'].sum()
x7 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Self-employed (Business activity)', 'Total Male'].sum()
x8 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Retired Person', 'Total Male'].sum()
x9 = prof_by_gender.loc[prof_by_gender['Profession'] == 'House Wife', 'Total Male'].sum()
x10 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Service (Private)', 'Total Male'].sum()

# %%
y= prof_by_gender.loc [prof_by_gender['Profession'] == 'Others (Please Specify)', 'Total Female'].sum()
y1 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Farming/Agriculture Activity', 'Total Female'].sum()
y2 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Unemployed', 'Total Female'].sum()
y3 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Public Sector Undertaking', 'Total Female'].sum()
y4 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Student', 'Total Female'].sum()
y5 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Professional Activity','Total Female'].sum()
y6 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Service (Government)', 'Total Female'].sum()
y7 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Self-employed (Business activity)', 'Total Female'].sum()
y8 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Retired Person', 'Total Female'].sum()
y9 = prof_by_gender.loc[prof_by_gender['Profession'] == 'House Wife', 'Total Female'].sum()
y10 = prof_by_gender.loc[prof_by_gender['Profession'] == 'Service (Private)', 'Total Female'].sum()

# %%
profession = ['Others (Please Specify)', 'Farming/Agriculture Activity', 'Unemployed',
       'Public Sector Undertaking', 'Student', 'Professional Activity',
       'Service (Government)', 'Self-employed (Business activity)',
       'Retired Person', 'House Wife', 'Service (Private)']

Males = [x,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10]

Females = [y,y1,y2,y3,y4,y5,y6,y7,y8,y9,y10]

# %%
Females
# Out:
# [12167, 1956, 1842, 569, 3508, 441, 296, 530, 135, 24596, 1706]

# %%
plt.bar(profession, Males, color='r')
plt.bar(profession, Females, bottom=Males, color='b')
plt.xticks(range(len(profession)), profession, rotation='vertical')
plt.xlabel("Profession of person")
plt.ylabel("Suicide victim count")
plt.title("Count of suicide victims belonging to different professions as per their gender")
plt.legend(["Males","Females"])
plt.show()
